# %% [markdown]
# # An analysis of the most popular repos on Github
# <img src="https://kanbanize.com/blog/wp-content/uploads/2014/11/GitHub.jpg" alt="github">
# _Areas of focus include: Type of repo, Size, Metrics of popularity, Languages used, Level of activity_
# <hr>
# _Data Source: https://www.kaggle.com/chasewillden/topstarredopensourceprojects _

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
git_df = pd.read_csv("topstarredopensourceprojects/TopStaredRepositories.csv")
git_df.head()
# Out:
#           Username         Repository Name  \
# 0     freeCodeCamp            freeCodeCamp
# 1             twbs               bootstrap
# 2  EbookFoundation  free-programming-books
# 3         facebook                   react
# 4               d3                      d3
#
#                                          Description      Last Update Date  \
# 0  The https://freeCodeCamp.com open source codeb...  2017-06-24T15:56:17Z
# 1  The most popular HTML, CSS, and JavaScript fra...  2017-06-24T15:40:21Z
# 2                 Freely available programming books  2017-06-23T01:09:34Z
# 3  A declarative, efficient, and flexible JavaScr...  2017-06-24T19:33:49Z
# 4     Bring data to life with SVG, Canvas and HTML.   2017-05-31T06:03:47Z
#
#      Language Number of Stars  \
# 0  JavaScript            290k
# 1  JavaScript            112k
# 2         NaN           87.8k
# 3  JavaScript           69.7k
# 4  JavaScript           65.7k
#
#                                                 Tags  \
# 0  nonprofits,certification,curriculum,react,node...
# 1     javascript,css,html,bootstrap,jekyll-site,scss
# 2                      education,list,books,resource
# 3                                                NaN
# 4                                      visualization
#
#                                                  Url
# 0       https://github.com/freeCodeCamp/freeCodeCamp
# 1                  https://github.com/twbs/bootstrap
# 2  https://github.com/EbookFoundation/free-progra...
# 3                  https://github.com/facebook/react
# 4                           https://github.com/d3/d3

# %%
git_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 0 to 979
# Data columns (total 8 columns):
# Username            980 non-null object
# Repository Name     980 non-null object
# Description         977 non-null object
# Last Update Date    980 non-null object
# Language            877 non-null object
# Number of Stars     980 non-null object
# Tags                489 non-null object
# Url                 980 non-null object
# dtypes: object(8)
# memory usage: 61.3+ KB

# %% [markdown]
# ### 1. Popular Repositories
# **Determining what constitutes a popular repository by extracting the range of maximum and minimum starred repositories**

# %%
git_df_max = git_df['Number of Stars'].str.contains('k').all()
git_df_max
# Out:
# True

# %%
git_df['Number of Stars']=git_df['Number of Stars'].str.replace('k','').astype(float)

# %%
git_df.head()
# Out:
#           Username         Repository Name  \
# 0     freeCodeCamp            freeCodeCamp
# 1             twbs               bootstrap
# 2  EbookFoundation  free-programming-books
# 3         facebook                   react
# 4               d3                      d3
#
#                                          Description      Last Update Date  \
# 0  The https://freeCodeCamp.com open source codeb...  2017-06-24T15:56:17Z
# 1  The most popular HTML, CSS, and JavaScript fra...  2017-06-24T15:40:21Z
# 2                 Freely available programming books  2017-06-23T01:09:34Z
# 3  A declarative, efficient, and flexible JavaScr...  2017-06-24T19:33:49Z
# 4     Bring data to life with SVG, Canvas and HTML.   2017-05-31T06:03:47Z
#
#      Language  Number of Stars  \
# 0  JavaScript            290.0
# 1  JavaScript            112.0
# 2         NaN             87.8
# 3  JavaScript             69.7
# 4  JavaScript             65.7
#
#                                                 Tags  \
# 0  nonprofits,certification,curriculum,react,node...
# 1     javascript,css,html,bootstrap,jekyll-site,scss
# 2                      education,list,books,resource
# 3                                                NaN
# 4                                      visualization
#
#                                                  Url
# 0       https://github.com/freeCodeCamp/freeCodeCamp
# 1                  https://github.com/twbs/bootstrap
# 2  https://github.com/EbookFoundation/free-progra...
# 3                  https://github.com/facebook/react
# 4                           https://github.com/d3/d3

# %%
max_stars=git_df['Number of Stars'].max()
min_stars=git_df['Number of Stars'].min()
mean_stars= git_df['Number of Stars'].mean()
print(max_stars,min_stars, mean_stars)
# Out:
# 290.0 6.4 12.98571428571427

# %%
popular_repos= git_df[git_df['Number of Stars'] > 51.0]

# %%
popular_repos.head(13)
# Out:
#            Username         Repository Name  \
# 0      freeCodeCamp            freeCodeCamp
# 1              twbs               bootstrap
# 2   EbookFoundation  free-programming-books
# 3          facebook                   react
# 4                d3                      d3
# 5            getify        You-Dont-Know-JS
# 6        tensorflow              tensorflow
# 7      sindresorhus                 awesome
# 8             vuejs                     vue
# 9           angular              angular.js
# 10     robbyrussell               oh-my-zsh
# 11           airbnb              javascript
# 12           github               gitignore
#
#                                           Description      Last Update Date  \
# 0   The https://freeCodeCamp.com open source codeb...  2017-06-24T15:56:17Z
# 1   The most popular HTML, CSS, and JavaScript fra...  2017-06-24T15:40:21Z
# 2                  Freely available programming books  2017-06-23T01:09:34Z
# 3   A declarative, efficient, and flexible JavaScr...  2017-06-24T19:33:49Z
# 4      Bring data to life with SVG, Canvas and HTML.   2017-05-31T06:03:47Z
# 5     A book series on JavaScript. @YDKJS on twitter.  2017-06-23T10:42:36Z
# 6   Computation using data flow graphs for scalabl...  2017-06-24T18:25:42Z
# 7                       Curated list of awesome lists  2017-06-24T17:26:02Z
# 8   A progressive, incrementally-adoptable JavaScr...  2017-06-24T15:38:55Z
# 9             AngularJS - HTML enhanced for web apps!  2017-06-24T06:25:23Z
# 10  A delightful community-driven (with 1,000+ con...  2017-06-23T19:24:49Z
# 11                             JavaScript Style Guide  2017-06-24T05:44:24Z
# 12        A collection of useful .gitignore templates  2017-06-24T08:48:29Z
#
#       Language  Number of Stars  \
# 0   JavaScript            290.0
# 1   JavaScript            112.0
# 2          NaN             87.8
# 3   JavaScript             69.7
# 4   JavaScript             65.7
# 5   JavaScript             62.0
# 6          C++             61.6
# 7          NaN             60.7
# 8   JavaScript             57.7
# 9   JavaScript             56.2
# 10       Shell             55.2
# 11  JavaScript             54.1
# 12         NaN             51.6
#
#                                                  Tags  \
# 0   nonprofits,certification,curriculum,react,node...
# 1      javascript,css,html,bootstrap,jekyll-site,scss
# 2                       education,list,books,resource
# 3                                                 NaN
# 4                                       visualization
# 5   book-series,javascript,training-materials,asyn...
# 6   tensorflow,python,machine-learning,deep-neural...
# 7       lists,awesome,unicorns,resources,awesome-list
# 8                   javascript,vue,framework,frontend
# 9                                                 NaN
# 10  zsh-configuration,shell,theme,productivity,ter...
# 11  arrow-functions,javascript,eslint,naming-conve...
# 12                                      gitignore,git
#
#                                                   Url
# 0        https://github.com/freeCodeCamp/freeCodeCamp
# 1                   https://github.com/twbs/bootstrap
# 2   https://github.com/EbookFoundation/free-progra...
# 3                   https://github.com/facebook/react
# 4                            https://github.com/d3/d3
# 5          https://github.com/getify/You-Dont-Know-JS
# 6            https://github.com/tensorflow/tensorflow
# 7             https://github.com/sindresorhus/awesome
# 8                        https://github.com/vuejs/vue
# 9               https://github.com/angular/angular.js
# 10          https://github.com/robbyrussell/oh-my-zsh
# 11               https://github.com/airbnb/javascript
# 12                https://github.com/github/gitignore
